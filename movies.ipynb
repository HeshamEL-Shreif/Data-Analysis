# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Import data set

# %%
movie=pd.read_csv("tmdb-movies.csv")

# %% [markdown]
# Show head of the data

# %%
movie.head(5)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# Show info of data to know data types of each column and number of null values and other

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
movie1=movie
movie['catigorie']=movie["genres"].apply(lambda title:str(title).split('|')[0])

# %% [markdown]
# Divide the genres into categories by split it

# %%
movie.head(5)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# Describe  to know details of each column

# %%
movie.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %% [markdown]
# relation between budget and each category
# and between revenue and each category
# and compare between them

# %%
g = sns.catplot(
    data=movie, kind="bar",
    x="revenue", y="catigorie",
     palette="dark", alpha=.9, height=14
)

# %% [markdown]
# revenue and each category

# %%
g = sns.catplot(
    data=movie, kind="bar",
    x="budget", y="catigorie", palette="tab10", alpha=.9, height=14
)

# %% [markdown]
# budget and each category

# %% [markdown]
# Analysis of the two previous graphs

# %% [markdown]
# Adventure category costs the highest budget and get the highest revenue.
# Action and Science Fiction :
# Science Fiction costs the same  budget and get more revenue
# animation cost less budget than Fantasy and get more revenue
# Drama and comedy nearly the same budgets but comedy gain more revenue
# crime and romance:
# romance less budget and more revenue
# and so on

# %% [markdown]
# Relation between popularity and each category

# %%
g = sns.catplot(
    data=movie, kind="bar",
    x="popularity", y="catigorie",
     palette="tab10", alpha=.9, height=14
)

# %% [markdown]
# Adventure have the most popularity
# and in the second stage the science fiction

# %% [markdown]
# Relation between release year and revenue

# %%
f, ax = plt.subplots(figsize=(15.5, 15.5))

sns.scatterplot(y="release_year", x="revenue",
                hue="catigorie",
                palette="tab10",
                sizes=(2, 16), linewidth=0,
                data=movie, ax=ax)
# Out:
# <AxesSubplot:xlabel='revenue', ylabel='release_year'>

# %% [markdown]
# before 2000 there are less film categories and less revenue
# after 2000 there are more variety in the categories of films and gain more revenue

# %% [markdown]
# Divide years into decades
# 1960 -> 1969 -> 60
# 1970 -> 1979  -> 70
# 1980 -> 1989  -> 80
# 1990 -> 1999  ->  90
# 2000 -> 2009    -> 20
# 2010 -> 2019   ->   21

# %%
movie['year_range']=movie['release_year'].apply( lambda year: 60 if(year in range(1960,1970))else 70 if(year in range(1970,1980)) else 80 if(year in range(1980,1990))else 90 if(year in range(1990,2000))else 20 if(year in range(2000,2010))else 21 if(year in range(2010,2020)) else 0)

# %% [markdown]
# Each category and its count throw each decade

# %%
f, ax = plt.subplots(figsize=(35, 20))
sns.despine(f)
sns.despine(f, left=True, top=True)
sns.histplot(
    movie,
    hue="year_range", x="catigorie",
    multiple="stack",
    palette="tab10",edgecolor=".5",
    linewidth=.8,

)
# Out:
# <AxesSubplot:xlabel='catigorie', ylabel='Count'>

# %% [markdown]
# in 60's  not all the film categories we see now was available  like war, history and  Tv movies
# in 90's the number of films are less than other decades
# in 20's  we found all categories are available and a large number of films
# from 60's to 90's number of films decreasing throw years
# and in 20's the number of films increases too much
# and back decreasing by 21's
# Action,Drama,Comedy and Horror are the most trending categories throw years
# but the most popular is Adventure from a previous graph but the number of Adventure films is too small
# POV: the more availability of film type can make people less interest to see it

# %% [markdown]
# divide each year into quarters

# %%
movie['year_part']=movie['release_date'].apply(lambda month: str(month).split("/")[0])
movie['year_part']=movie['year_part'].apply(lambda month: "q1" if(int(month) in range(1,4))else "q2" if(int(month) in range(4,7))else "q3" if(int(month) in range(7,10)) else "q4" if (int(month) in range(10,13)) else 0 )

# %% [markdown]
# Relation between revenue and the quarter it releases in

# %%
g = sns.catplot(
    data=movie, kind="bar",
    x="year_part", y="revenue",
    palette="tab10", alpha=1, height=20
)

# %% [markdown]
# The films that released in second quarter of the year gets more revenue
